# %% [markdown]
# # 01 — Data Exploration

# %%
# !pip -q install -r ../requirements.txt

# %%
from src.data_loader import load_series
from src.visualization import plot_series

df = load_series('../data/raw/daily_energy_synthetic.csv')
df.head()

# %%
plot_series(df, title='Daily Energy (Synthetic)')
